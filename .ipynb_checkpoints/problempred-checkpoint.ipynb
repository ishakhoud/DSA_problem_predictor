# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Problems_Days.csv')
df.head()
# Out:
#    Days  ProblemsSolved
# 0     4              10
# 1     7              20
# 2    15              40
# 3    30              80
# 4    20              30

# %%
x = df.iloc[:,:-1].values
x[0:5]
# Out:
# array([[ 4],
#        [ 7],
#        [15],
#        [30],
#        [20]])

# %%
y=df.iloc[:,-1].values
y[0:5]
# Out:
# array([10, 20, 40, 80, 30])

# %%
plt.scatter(x , y )

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2 , random_state = 0)
y_test.shape
# Out:
# (3,)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train , y_train )
# Out:
# LinearRegression()

# %%
model.predict([[4] , [7] , [140] ])
# Out:
# array([ 11.07214663,  16.66806222, 264.75365317])
