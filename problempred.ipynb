# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Problems_Days.csv')
df.head()
# Out:
#    Days  ProblemsSolved
# 0     1               1
# 1     2               6
# 2     4              10
# 3     6              15
# 4     7              20

# %%
x = df.iloc[:,:-1].values
x[0:5]
# Out:
# array([[1],
#        [2],
#        [4],
#        [6],
#        [7]])

# %%
y=df.iloc[:,-1].values
y[0:5]
# Out:
# array([ 1,  6, 10, 15, 20])

# %%
plt.scatter(x , y )

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.5 , random_state = 0)
y_test.shape
# Out:
# (11,)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train , y_train )
# Out:
# LinearRegression()

# %%
model.predict([[4] , [7] , [140] ])
# Out:
# array([ 15.12585339,  20.79962341, 272.33676098])

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([ 58.62475688, 139.94879384, 264.77173429,  11.34334004,
#        102.12366037,  83.21109363, 158.86136057, 245.85916755,
#         45.38596016, 257.2067076 ,  20.79962341])

# %%
error = y_pred - y_test
error
# Out:
# array([  8.62475688, -15.05120616,  -1.22826571,   5.34334004,
#          2.12366037, -11.78890637, -16.13863943,  11.85916755,
#         15.38596016,  -4.7932924 ,   0.79962341])

# %%
plt.scatter(x_test , y_test)
plt.plot(x_test , y_pred , color = "green")

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test , y_pred)
r2
# Out:
# 0.9880759877212035
